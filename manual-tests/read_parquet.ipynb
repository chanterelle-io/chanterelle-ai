# %%
import pandas as pd
filepath = "/Users/alieladi/Downloads/12cb6999-7697-4468-b5d2-00ac2c59f2c8.parquet"

# read file
df = pd.read_parquet(filepath)
df.head()
# Out:
#    id        name                  email signup_date    status     segment
# 0   1  Customer 1  customer1@example.com  2025-12-19    active  mid-market
# 1   2  Customer 2  customer2@example.com  2026-01-03    active  mid-market
# 2   3  Customer 3  customer3@example.com  2025-12-15    active  enterprise
# 3   4  Customer 4  customer4@example.com  2026-04-17  inactive  individual
# 4   5  Customer 5  customer5@example.com  2025-12-24    active  mid-market
