# %%
import pandas as pd
filepath = "/Users/alieladi/Downloads/fe2969a5-757d-4313-8fef-cf457c318d00.parquet"

# read file
df = pd.read_parquet(filepath)
df.head()
# Out:
#       segment  customer_count   sample_name
# 0  enterprise               5  Customer 158
# 1  individual               5  Customer 110
# 2  mid-market               1  Customer 124
# 3         smb               5  Customer 129
